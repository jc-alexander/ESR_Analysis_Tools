# %%
from ESR_tools import esr_tools
import numpy as np

from matplotlib import pyplot as plt

# %%
folder = 'data/'
name = '2020_04_30_0314Angular_171_T2_sweep1_avgs_502.004mT2430.198MHz_10sSRT_10pi_T2_{}.txt.npy'

# %%
I = np.load(folder+name.format('Is'))
Q = np.load(folder+name.format('Qs'))
t = np.load(folder+name.format('t'))
wait = np.load(folder+name.format('waits'))

# %%
np.save('data/T2_data',[I,Q,t,wait])
# Out:
# /Users/jalexander/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
[I,Q,t,wait] = np.load('data/T2_data.npy',allow_pickle=True)

# %%
plt.plot(I[0][0])

# %%
T2_data = esr_tools.T2(wait,I,Q,int_lims=[90,130],T2_type='normal')

# %%
[amp,T2],[amp_err,T2_err] = T2_data.analyse()
# Out:
# Calculating echos with 1 averages
#
# T2 = 226.436 $\pm$ 16.450 μs
